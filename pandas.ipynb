# %%
import pandas as pd

# %%
carsales=pd.read_csv("car sales.csv")

# %%
carsales.groupby(["Make"]).mean().plot()

# %%
carsales["Doors"].plot()

# %%
carsales["Doors"].hist()

# %%
pd.crosstab(carsales["Make"],carsales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
carsales["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
carsales["Price"]=carsales["Price"].str.replace("[\$,\,\.]","").astype(int)

# %%
carsales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %%
carsales["Price"].plot()

# %% [markdown]
# # Manipulating data

# %%
carsales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
carsales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000

# %%
carmissing=pd.read_csv("car missing.csv")

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carmissing["Odometer"].fillna(carmissing["Odometer"].mean(),inplace=True)

# %%
carmissing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carmissing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
cardmissingdropped=carmissing.dropna()

# %%
cardmissing=carmissing

# %%
carmissingdropped=cardmissingdropped

# %%
carmissingdropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
carmissingdropped.to_csv("car missing dropped.csv")

# %%
seats=pd.Series([5,5,5,5,5])

# %%
carmissing["Seats"]=seats

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    NaN
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
carmissing["Seats"].fillna(5,inplace=True)

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    5.0
# 6   Honda    NaN       NaN    4.0   $7,500    5.0
# 7   Honda   Blue       NaN    4.0      NaN    5.0
# 8  Toyota  White   60000.0    NaN      NaN    5.0
# 9     NaN  White   31600.0    4.0   $9,700    5.0

# %%
carmissing["Per 100 km"]=[3.5,4.6,2.7,2.6,9.2,6.2,9.2,2.5,3.9,3.4]

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Per 100 km
# 0  Toyota  White  150043.0    4.0   $4,000    5.0         3.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0         4.6
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0         2.7
# 3     BMW  Black   11179.0    5.0  $22,000    5.0         2.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0         9.2
# 5  Toyota  Green       NaN    4.0   $4,500    5.0         6.2
# 6   Honda    NaN       NaN    4.0   $7,500    5.0         9.2
# 7   Honda   Blue       NaN    4.0      NaN    5.0         2.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0         3.9
# 9     NaN  White   31600.0    4.0   $9,700    5.0         3.4

# %%
carmissing["Total fuel"]=pd.Series(carmissing["Odometer"]/100*carmissing["Per 100 km"])

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Per 100 km  Total fuel
# 0  Toyota  White  150043.0    4.0   $4,000    5.0         3.5    5251.505
# 1   Honda    Red   87899.0    4.0   $5,000    5.0         4.6    4043.354
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0         2.7         NaN
# 3     BMW  Black   11179.0    5.0  $22,000    5.0         2.6     290.654
# 4  Nissan  White  213095.0    4.0   $3,500    5.0         9.2   19604.740
# 5  Toyota  Green       NaN    4.0   $4,500    5.0         6.2         NaN
# 6   Honda    NaN       NaN    4.0   $7,500    5.0         9.2         NaN
# 7   Honda   Blue       NaN    4.0      NaN    5.0         2.5         NaN
# 8  Toyota  White   60000.0    NaN      NaN    5.0         3.9    2340.000
# 9     NaN  White   31600.0    4.0   $9,700    5.0         3.4    1074.400

# %%
carmissing["Total fuel"].fillna(carmissing["Total fuel"].mean(),inplace=True)

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Per 100 km    Total fuel
# 0  Toyota  White  150043.0    4.0   $4,000    5.0         3.5   5251.505000
# 1   Honda    Red   87899.0    4.0   $5,000    5.0         4.6   4043.354000
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0         2.7   5434.108833
# 3     BMW  Black   11179.0    5.0  $22,000    5.0         2.6    290.654000
# 4  Nissan  White  213095.0    4.0   $3,500    5.0         9.2  19604.740000
# 5  Toyota  Green       NaN    4.0   $4,500    5.0         6.2   5434.108833
# 6   Honda    NaN       NaN    4.0   $7,500    5.0         9.2   5434.108833
# 7   Honda   Blue       NaN    4.0      NaN    5.0         2.5   5434.108833
# 8  Toyota  White   60000.0    NaN      NaN    5.0         3.9   2340.000000
# 9     NaN  White   31600.0    4.0   $9,700    5.0         3.4   1074.400000

# %%
carmissing["Wheel"]=4

# %%
carmissing["Passed road safety"]=True

# %%
carmissing
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Per 100 km    Total fuel  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0         3.5   5251.505000
# 1   Honda    Red   87899.0    4.0   $5,000    5.0         4.6   4043.354000
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0         2.7   5434.108833
# 3     BMW  Black   11179.0    5.0  $22,000    5.0         2.6    290.654000
# 4  Nissan  White  213095.0    4.0   $3,500    5.0         9.2  19604.740000
# 5  Toyota  Green       NaN    4.0   $4,500    5.0         6.2   5434.108833
# 6   Honda    NaN       NaN    4.0   $7,500    5.0         9.2   5434.108833
# 7   Honda   Blue       NaN    4.0      NaN    5.0         2.5   5434.108833
# 8  Toyota  White   60000.0    NaN      NaN    5.0         3.9   2340.000000
# 9     NaN  White   31600.0    4.0   $9,700    5.0         3.4   1074.400000
#
#    Wheel  Passed road safety
# 0      4                True
# 1      4                True
# 2      4                True
# ...

# %%
carmissing.drop("Passed road safety",axis=1)
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Per 100 km    Total fuel  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0         3.5   5251.505000
# 1   Honda    Red   87899.0    4.0   $5,000    5.0         4.6   4043.354000
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0         2.7   5434.108833
# 3     BMW  Black   11179.0    5.0  $22,000    5.0         2.6    290.654000
# 4  Nissan  White  213095.0    4.0   $3,500    5.0         9.2  19604.740000
# 5  Toyota  Green       NaN    4.0   $4,500    5.0         6.2   5434.108833
# 6   Honda    NaN       NaN    4.0   $7,500    5.0         9.2   5434.108833
# 7   Honda   Blue       NaN    4.0      NaN    5.0         2.5   5434.108833
# 8  Toyota  White   60000.0    NaN      NaN    5.0         3.9   2340.000000
# 9     NaN  White   31600.0    4.0   $9,700    5.0         3.4   1074.400000
#
#    Wheel
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
# 5      4
# 6      4
# 7      4
# 8      4
# 9      4
