# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
sam=np.random.randn(10)

# %%
plt.plot(sam);

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,15]

# %%
plt.plot(x)

# %%
plt.plot(y);

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
ax.set(title="sample",xlabel="x",ylabel="y");

# %%
fig.savefig("sample.png")

# %%
x=np.linspace(0,100)

# %%
x
# Out:
# array([  0.        ,   2.04081633,   4.08163265,   6.12244898,
#          8.16326531,  10.20408163,  12.24489796,  14.28571429,
#         16.32653061,  18.36734694,  20.40816327,  22.44897959,
#         24.48979592,  26.53061224,  28.57142857,  30.6122449 ,
#         32.65306122,  34.69387755,  36.73469388,  38.7755102 ,
#         40.81632653,  42.85714286,  44.89795918,  46.93877551,
#         48.97959184,  51.02040816,  53.06122449,  55.10204082,
#         57.14285714,  59.18367347,  61.2244898 ,  63.26530612,
#         65.30612245,  67.34693878,  69.3877551 ,  71.42857143,
#         73.46938776,  75.51020408,  77.55102041,  79.59183673,
#         81.63265306,  83.67346939,  85.71428571,  87.75510204,
#         89.79591837,  91.83673469,  93.87755102,  95.91836735,
#         97.95918367, 100.        ])

# %%
fig,ax=plt.subplots(figsize=(10,5));
plt.plot(x,np.sin(x));

# %%
dic={"Marlboro":16,"Benson":14,"Easse lite":10}

# %%
fig,ax=plt.subplots()
ax.bar(list(dic.keys()),list(dic.values()));
ax.set(title="Favorite cigarette",xlabel="Brand",ylabel="Price");

# %%
fig,ax=plt.subplots()
ax.barh(list(dic.keys()),list(dic.values()));

# %%
x=np.random.normal(size=1000)

# %%
plt.hist(x);

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(20,10));
ax1.plot(x,x/2);
ax2.scatter(np.random.randn(10),np.random.randn(10));
ax3.bar(list(dic.keys()),list(dic.values()));
ax4.hist(np.random.normal(size=1000));

# %%
cs=pd.read_csv("car sales.csv")

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cs["Price"]=cs["Price"].str.replace("[/$,/,/.]","")

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
cs["Price"]=cs["Price"].str[:-2]

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
cs["Price"]=cs["Price"].astype(int)

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
cs["Price"].plot()

# %%
cs["Total Sales"]=np.cumsum(cs["Price"])

# %%
csS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-e7da5cb5c7d3> in <module>
# ----> 1 csS
#
# NameError: name 'csS' is not defined

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
# 6   Honda   Blue          45698      4   7500        53500
# 7   Honda   Blue          54738      4   7000        60500
# 8  Toyota  White          60000      4   6250        66750
# 9  Nissan  White          31600      4   9700        76450

# %%
cs["Sales Date"]=pd.date_range("31/3/2020",periods=len(cs))

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales Sales Date
# 0  Toyota  White         150043      4   4000         4000 2020-03-31
# 1   Honda    Red          87899      4   5000         9000 2020-04-01
# 2  Toyota   Blue          32549      3   7000        16000 2020-04-02
# 3     BMW  Black          11179      5  22000        38000 2020-04-03
# 4  Nissan  White         213095      4   3500        41500 2020-04-04
# 5  Toyota  Green          99213      4   4500        46000 2020-04-05
# 6   Honda   Blue          45698      4   7500        53500 2020-04-06
# 7   Honda   Blue          54738      4   7000        60500 2020-04-07
# 8  Toyota  White          60000      4   6250        66750 2020-04-08
# 9  Nissan  White          31600      4   9700        76450 2020-04-09

# %%
cs.plot("Sales Date","Total Sales")

# %%
cs.plot("Odometer (KM)","Price",kind="scatter")

# %%
arr=np.random.randn(10,4)

# %%
arr=pd.DataFrame(arr)

# %%
arr.columns=['a','b','c','d']

# %%
arr
# Out:
#           a         b         c         d
# 0 -0.885561  0.274206 -0.432255  3.684774
# 1 -0.111644 -0.829951 -0.807289  0.056464
# 2 -0.592459 -0.034466 -1.549185  0.388073
# 3 -0.426634 -0.795863  0.543965  0.757776
# 4 -2.529885  1.751871 -1.013012 -0.528256
# 5 -0.810758 -0.330796 -1.391179 -2.805104
# 6 -0.493483 -1.023375 -0.833725 -0.685517
# 7 -1.253121  2.172400 -1.647558 -0.234263
# 8 -0.186732  1.353749  1.884777 -0.593807
# 9  0.031915  0.119002 -2.100530  0.296212

# %%
arr.plot(kind='bar')

# %%
cs.plot("Make","Odometer (KM)",kind="bar")

# %%
plt.hist(cs["Odometer (KM)"]);

# %%
plt.hist(cs["Price"],bins=20);

# %%
hd=pd.read_csv("heart.csv")

# %%
plt.hist(hd["age"],bins=50)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  2.,  4.,  0.,  2.,  3.,  4.,  3., 10.,
#          8.,  8., 11.,  8.,  7.,  5.,  7.,  5.,  7., 12., 13.,  0.,  8.,
#         16.,  8., 11., 17., 19., 14., 11.,  8., 11.,  9., 10.,  8.,  7.,
#          9.,  4.,  3.,  4.,  3.,  0.,  0.,  1.,  0.,  1.,  1.]),
#  array([29.  , 29.96, 30.92, 31.88, 32.84, 33.8 , 34.76, 35.72, 36.68,
#         37.64, 38.6 , 39.56, 40.52, 41.48, 42.44, 43.4 , 44.36, 45.32,
#         46.28, 47.24, 48.2 , 49.16, 50.12, 51.08, 52.04, 53.  , 53.96,
#         54.92, 55.88, 56.84, 57.8 , 58.76, 59.72, 60.68, 61.64, 62.6 ,
#         63.56, 64.52, 65.48, 66.44, 67.4 , 68.36, 69.32, 70.28, 71.24,
#         72.2 , 73.16, 74.12, 75.08, 76.04, 77.  ]),
#  <a list of 50 Patch objects>)

# %%
hd.plot.hist(subplots=True,figsize=(10,50));

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
plt.style.use("seaborn")
fig,ax=plt.subplots(figsize=(10,5))
ax.scatter(hd["age"],hd["chol"],c=hd["sex"],cmap="summer")
ax.axhline(hd["chol"].mean(),linestyle="--");

# %%
plt.style.available
# Out:
# ['seaborn-paper',
#  'seaborn-dark-palette',
#  'dark_background',
#  'seaborn-whitegrid',
#  'seaborn-white',
#  'tableau-colorblind10',
#  'seaborn-ticks',
#  '_classic_test',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-muted',
#  'grayscale',
#  'fast',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'seaborn-deep',
#  'fivethirtyeight',
#  'seaborn-notebook',
#  'seaborn-talk',
#  'seaborn-darkgrid',
#  'seaborn',
#  'bmh',
#  'seaborn-poster',
#  'classic',
#  'Solarize_Light2']
