# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("hc/mc.csv")

# %%
data.head(1)
# Out:
#    CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1  Male   19                  15                      39

# %%
x=data.iloc[:,[3,4]].values

# %%
import scipy.cluster.hierarchy as sch

# %%
dendrogram=sch.dendrogram(sch.linkage(x,method="ward"))

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hc=AgglomerativeClustering(n_clusters=5,affinity="euclidean",linkage="ward")

# %%
yhc=hc.fit_predict(x)

# %%
plt.scatter(x[yhc==0,0],x[yhc==0,1],s=100,c="black")
plt.scatter(x[yhc==1,0],x[yhc==1,1],s=100,c="gray")
plt.scatter(x[yhc==2,0],x[yhc==2,1],s=100,c="blue")
plt.scatter(x[yhc==3,0],x[yhc==3,1],s=100,c="orange")
plt.scatter(x[yhc==4,0],x[yhc==4,1],s=100,c="yellow");
